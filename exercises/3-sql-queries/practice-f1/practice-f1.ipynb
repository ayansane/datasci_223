# %% [markdown]
# # Practice using F1 data from Ergast API (compiled by Kaggle)
# [F1 World Championship 1950-2023](https://www.kaggle.com/datasets/rohanrao/formula-1-world-championship-1950-2020)

# %%
# %pip install pandas sqlalchemy ipython-sql
# Out:
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.1-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.25.1-py3.11.egg-info due to invalid metadata entry 'name'
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (2.0.2)
# Requirement already satisfied: sqlalchemy in /opt/homebrew/lib/python3.11/site-packages (2.0.25)
# Collecting ipython-sql
#   Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/homebrew/lib/python3.11/site-packages (from sqlalchemy) (4.7.1)
# Collecting prettytable (from ipython-sql)
#   Downloading prettytable-3.9.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: ipython in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from ipython-sql) (8.10.0)
# Collecting sqlparse (from ipython-sql)
#   Downloading sqlparse-0.4.4-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: six in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: backcall in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-sql) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-sql) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-sql) (2.14.0)
# Requirement already satisfied: stack-data in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-sql) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-sql) (5.9.0)
# Requirement already satisfied: pexpect>4.3 in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-sql) (4.8.0)
# Requirement already satisfied: appnope in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-sql) (0.1.3)
# Requirement already satisfied: wcwidth in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from prettytable->ipython-sql) (0.2.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython->ipython-sql) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/alfayansane1/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Downloading prettytable-3.9.0-py3-none-any.whl (27 kB)
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.26.1-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/numpy-1.25.1-py3.11.egg-info due to invalid metadata entry 'name'
# Installing collected packages: sqlparse, prettytable, ipython-sql
# Successfully installed ipython-sql-0.5.0 prettytable-3.9.0 sqlparse-0.4.4
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load packages
import pandas as pd
import zipfile
import os
from sqlalchemy import create_engine

# Connect to an in-memory SQLite database
engine = create_engine('sqlite:///:memory:')

# Configure the SQL magic
# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# Use %sql magic to connect to the SQLite database
# %sql sqlite:///:memory:

# Unzip the data
with zipfile.ZipFile('F1.zip', 'r') as zip_ref:
    zip_ref.extractall('data')

# Load each CSV into a DataFrame
tables = []
for f in os.listdir('data'):
    if f.endswith('.csv'):
        table_name = f.replace('.csv', '')
        file_path = os.path.join('data', f)
        # tables[table_name] = pd.read_csv(file_path)
        tables.append(table_name)
        globals()[table_name] = pd.read_csv(file_path)


# Use %sql magic to create temporary tables
for table_name in tables:
    # %sql DROP TABLE IF EXISTS {table_name}
    # %sql --persist {table_name}

# %%
# Query using %sql magic
res = %sql SELECT * FROM results LIMIT 5
display(res)
# Out:
#    index  resultId  raceId  driverId  constructorId number  grid position  \
# 0      0         1      18         1              1     22     1        1
# 1      1         2      18         2              2      3     5        2
# 2      2         3      18         3              3      7     7        3
# 3      3         4      18         4              4      5    11        4
# 4      4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# 1         41    3       1:27.739         217.586         1
# 2         41    5       1:28.090         216.719         1
# 3         58    7       1:28.603         215.464         1
# 4         43    1       1:27.418         218.385         1

# %%
# %sql SELECT * FROM circuits LIMIT 5
# Out:
#    index  circuitId   circuitRef                            name  \
# 0      0          1  albert_park  Albert Park Grand Prix Circuit
# 1      1          2       sepang    Sepang International Circuit
# 2      2          3      bahrain   Bahrain International Circuit
# 3      3          4    catalunya  Circuit de Barcelona-Catalunya
# 4      4          5     istanbul                   Istanbul Park
#
#        location    country       lat        lng  alt  \
# 0     Melbourne  Australia -37.84970  144.96800   10
# 1  Kuala Lumpur   Malaysia   2.76083  101.73800   18
# 2        Sakhir    Bahrain  26.03250   50.51060    7
# 3      Montmeló      Spain  41.57000    2.26111  109
# 4      Istanbul     Turkey  40.95170   29.40500  130
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4         http://en.wikipedia.org/wiki/Istanbul_Park
